# %% [markdown]
# ### datconv test
#
# 20250429
#
# Modification of datconv.py
#
# - Added correction of Docstring
# - Modified methods
# - Added plot method
# - Added AdvAcConv(AcConv) class
#
# AdvAcConv(AcConv) class
# - Deleted data above 6.8eV
# - Deleted areas that exceeded the maximum count
#
# countingCorrection
# - AC-2, AC-3 Max: 2000cps
# - AC-5, AC-2S Max: 4000cps

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from reader import datconv as dc

import warnings
warnings.simplefilter('ignore')
# warnings.resetwarnings()
# warnings.simplefilter('ignore', FutureWarning)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
target_dat_files =[r'Datas\6T 20150615184222_6885.dat',
                   r'Datas\DMQA 20150617175451_6900.dat',
                   r"Datas\DP-Ant 20171003200344_8068.dat",
                   r"Datas\DPP 20150511185120_6834.dat",
                   r"Datas\PTCBI 20170620205101_7916.dat",
                   r"Datas\Quinacridone 20150424195744_6798.dat"]

# %%
# with over flow (without trimming)
inst_wo_trim=[]
for fi in target_dat_files:
    temp_acdata = dc.AcConv(fi)
    temp_acdata.convert()
    temp_acdata.plot_ax()
    inst_wo_trim.append(temp_acdata)

# %%
inst_w_trim=[]
for fi in target_dat_files:
    temp2_acdata = dc.AdvAcConv(fi)
    temp2_acdata.convert()
    temp2_acdata.plot_ax()
    inst_w_trim.append(temp2_acdata)
