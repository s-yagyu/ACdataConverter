# %%
# For Colab

# ユーザー認証
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive')

import sys
ROOT_PATH = 'drive/My Drive/ACdataConverter/'
sys.path.append(ROOT_PATH)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Creating a list from dat files
#
# Read all dat files in a folder and create a list of metadata (Excel)

# %%
from pathlib import Path

from acdatconv import datconv as dv
from acdatconv import datlib as dlib

# %%
import warnings
warnings.simplefilter('ignore')

# %load_ext autoreload
# %autoreload 2

# %%
# DATA_File=r"validationData"
DATA_File='drive/My Drive/ACdataConverter/validationData'
f_path = Path(DATA_File)

tg_list = list(f_path.glob('*.dat'))
print(tg_list)

# %%
out_file='drive/My Drive/ACdataConverter/validationData/test.xlsx'
df_vd = dlib.dat_list_make(data_path=f_path, figout=True, out_file_name=out_file)

# %%
df_vd.info()

# %%
df_vd
